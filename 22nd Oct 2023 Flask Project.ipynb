# %% [markdown]
# # 22nd Oct 2023 : Flask Project

# %%
#### for this project we need to make an account in the weather API website. which is given below
###openweathermap.org

# then after making an account, go to profile and see your API key which will be needed in this project

# now we need to make a code to run the api key

# %% [markdown]
# ![image.png](attachment:1912dab0-16e0-43a7-a1ad-4829f494668f.png)

# %%
# we need a API URL 
# here worked in the website "api.openweathermap.org/data/2.5/weather"

# with the help of the data directily we cannot be able to get any data. for that, we have to pass certiain things inside the data to fetch the data. 

# if you use the above website, you will see that the above website is asking for three parameters which we have to put in there. 

# for EXAMPLE, we can use the website link, then press question mark (?) then 'q' for querry that what is going to take. 
# this querry is taking a city name and second is which metrics or units is taking,

# %% [markdown]
# ![image.png](attachment:84d88114-0d13-42f6-ab56-3de7c6c22ebd.png)

# %%
# here we can understand how to place querries.

# %%
api.openweathermap.org/data/2.5/weather?q=london&units=metric&appid=392b2f6ee7242533cb746146fadec881
# Out:
#   Cell In[6], line 1
#     api.openweathermap.org/data/2.5/weather?q=london&units=metric&appid=392b2f6ee7242533cb746146fadec881
#                                                                           ^
# SyntaxError: invalid decimal literal

# %% [markdown]
# ![image.png](attachment:f23b44bf-9154-4d50-90d0-ca260ea6c341.png)

# %%
# after using the querries I can get the querries. given above.

# %%
# whenever someone is giving an API, you have to find out whether it is a get API, or post API, whether is a put API, delete API,
# second thing is what and all parameter we have to pass in the API. for EXAMPLE, in the above picture, we can clearly see that we have to pass the longitude, latitude, part, then we have to pass the API key.

## # whoever going to expose the API, theey will always try to give you the doccumentation for effortlessly making the work. 

# doccumentation means what parameter you have supposed to pass. and what kind of sample response you are going to recieve. 

## if we are change the city name in the querry, we will be able to get the information also for the Paris city.

# %%
# 2.5 is free version, 3.0 is the pay system that's why we are useing the free versions

# %%
# for knowing how many parameter is taking you can go to open weather app and try to search, you also find it in google which can give you the answer.

# %%
# Another EXAMPLE is RAZORPAY

# %%
# search razorpay api docs in google,

# %%
## we will make a program so that, through python we will be able to hit the API

# %% [markdown]
# #### we will make a program

# %%
# providing API key and url

apikey = '392b2f6ee7242533cb746146fadec881'
url = "https://api.openweathermap.org/data/2.5/weather"

# %%
## creating parameters to store the data into a dictionary
params = {
    'q' : 'london',
    'appid' : apikey,
    'units' : 'metric'}

## these are the three parameter that my API os going to take

# %%
## now through python we have to pass or execute this to get the data

# %%
import requests
requests.get(url, params=params)

## if everythin is right, it will provide me a response
# Out:
# <Response [200]>

# %%
# storing the response in the data variable

data = requests.get(url, params=params)

# %%
data
# Out:
# <Response [200]>

# %%
# now, from the response we have to extract the data
# for that, we can use the json format

# %%
data.json()
# Out:
# {'coord': {'lon': -0.1257, 'lat': 51.5085},
#  'weather': [{'id': 802,
#    'main': 'Clouds',
#    'description': 'scattered clouds',
#    'icon': '03d'}],
#  'base': 'stations',
#  'main': {'temp': 13.26,
#   'feels_like': 13.02,
#   'temp_min': 11.49,
#   'temp_max': 14.74,
#   'pressure': 1017,
#   'humidity': 91,
#   'sea_level': 1017,
#   'grnd_level': 1013},
#  'visibility': 10000,
#  'wind': {'speed': 2.77, 'deg': 271, 'gust': 4.84},
#  'clouds': {'all': 35},
#  'dt': 1724912578,
#  'sys': {'type': 2,
#   'id': 2091269,
#   'country': 'GB',
#   'sunrise': 1724908141,
#   'sunset': 1724957648},
#  'timezone': 3600,
#  'id': 2643743,
#  'name': 'London',
#  'cod': 200}

# %%
# trying to fetch the data from API 3.0

url = 'https://api.openweathermap.org/data/3.0/onecall/timemachine' ## cannot fetch the data as this API is subscription based
apikey = 'b2f7276693524dc1283929277faa0eae'

# %%
import requests

requests.get(url1, params={'appid' : apikey})
# Out:
# <Response [401]>

# %%
## it fetchinng the error response because it is a paid one. you have to take subscription for using this API

# %%
url2 = 'https://api.openweathermap.org/data/2.5/history/city'

data2 = requests.get(url2, params={'appid' : apikey})
data2
# Out:
# <Response [401]>

# %%
url3 = "https://api.openweathermap.org/data/2.5/weather" 

appkey = "392b2f6ee7242533cb746146fadec881"


parameters = {
    "id" : "23.7097° N",
    "lon" : "87.2768° E",
    "appid" : appkey,
    "units" : 'metric'
    }

# %%
import requests

requests.get(url3, params=parameters)
# Out:
# <Response [400]>

# %%
urrl = "https://api.openweathermap.org/data/2.5/weather"
appkey =  "392b2f6ee7242533cb746146fadec881"

paramm = {"q" : "pandaveswar",
          'appid' : appkey,
          #"units" : 'metric'
          }

import requests

requests.get(urrl,params=paramm)
# Out:
# <Response [200]>

# %%
data = requests.get(urrl,params=paramm)

# %%
data.json()
# Out:
# {'coord': {'lon': 87.2704, 'lat': 23.7172},
#  'weather': [{'id': 721,
#    'main': 'Haze',
#    'description': 'haze',
#    'icon': '50d'}],
#  'base': 'stations',
#  'main': {'temp': 306.12,
#   'feels_like': 313.12,
#   'temp_min': 306.12,
#   'temp_max': 306.12,
#   'pressure': 1002,
#   'humidity': 70,
#   'sea_level': 1002,
#   'grnd_level': 992},
#  'visibility': 5000,
#  'wind': {'speed': 3.6, 'deg': 90},
#  'clouds': {'all': 40},
#  'dt': 1724915172,
#  'sys': {'type': 1,
#   'id': 9144,
#   'country': 'IN',
#   'sunrise': 1724889113,
#   'sunset': 1724934734},
#  'timezone': 19800,
#  'id': 1269280,
#  'name': 'Pandaveswar',
#  'cod': 200}

# %%
# the entire thing we need to convert in a small project and that project we are going to deploy on a cloud. 

# let assume someone does not know the coding, so we will ask for city,location, basically datas and I will give the data.

# %% [markdown]
# #### Steps for this project

# %%
## 1. Build this app in local
## 2. push this is git
## 3. deploy on cloud
## 4. test it

# %% [markdown]
# #### Steps for making application API

# %%
## first we need to open a flask

## first create a new folder in the workspace (name = weather_app)

## we need an UI where everyone put the information needed to run the API. for that we have to make another folder (name = templates) inside the weather_app

## inside the template folder we will make a index.html file.

## inside the main folder (weather_app), we will make a python file (named = app.py)

### we need to make these file in the same manner for every project

## whenever we make a project, we need to make some sort of installation, some external libraries also. 
## in this cloud, everything is installed (request, flask, python, etc.) because cloud is going to give a blank system. {these are called dipendency file}

## for that, we will make another file named requirements.txt on the weather_app folder. for making the nessesary libraries

## as we can see we are on the main directory/workspace. we need to go in the directory or folder named weaather_app.

## for that, we need to type "cd weather_app" to go to the directory. 

## for see the files on the folder, type "ls" on bash terminal

## now close everything. (tabs, terminal, you can also delete the resto of the file which we not need in this project like app.py, README, requirements.txt which was on the external di)

## only the files which I made and the .vscode file will remain in the directory. 

## the very first code will be in the index.html file. here we will make a form kind of structure in which people will find the name of the city

## when people give the city name, it will provide all the returns from the API.

# %%
# in the html page, we will provide the below code

# %%
<!DOCTYPE html>
<html lang="en">
<head>
</head>
<body>
    <title> Search Page </title>
    <div-class = "content">
        <h1 style="text-allign: center"> Search</h1>

        <div class="form">
            <form-action="/weatherapp" method ="POST">
                <input type="text" name="city" id="city">
                <input type="submit" value="Search">
            </form>
        </div>
    </div>
</body>
</html>
# Out:
#   Cell In[1], line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %%
## for checking the HTML file, you can download this and open with your browser. 

## this will look like this

# %% [markdown]
# ![image.png](attachment:ffe9dc36-9ae6-4abe-b8cb-092f81bce724.png)

# %%
<!DOCTYPE html>
<html lang="en">
<head>
    <title>Search Page</title>
</head>
<body>
    <div class="content">
        <h1 style="text-align: center">Search</h1>

        <div class="form">
            <form action="/weatherapp" method="POST">
                <label for="city">Enter City:</label>
                <input type="text" name="city" id="city">
                <label for="units">Enter Units:</label>
                <input type="text" name="units" id="units">
                <label for="appid">Enter API Key:</label>
                <input type="text" name="appid" id="appid">
                <input type="submit" value="Search">
            </form>
        </div>
    </div>
</body>
</html>
# Out:
#   Cell In[6], line 1
#     <!DOCTYPE html>
#     ^
# SyntaxError: invalid syntax

# %%
## which will look like this

# %% [markdown]
# ![image.png](attachment:d9a4f435-7eb7-4009-9959-2990e1a6dca6.png)

# %%
## now we will host this form into a cloud

## step number 1 is completed (Form Creation)

# %%
## now we have to write a logic or python code in the app.py file

# %%
# code in app.py

from flask import Flask, render_template, request
import requests

app=Flask(__name__)

@app.route('/')
def homepage():
    return render_template("index.html")


if __name__ == '__main__':
    app.run(host='0.0.0.0', port = 5002)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 3
#       1 # code in app.py
# ----> 3 from flask import Flask, render_template, request
#       4 import requests
#       6 app=Flask(__name__)
#
# ModuleNotFoundError: No module named 'flask'

# %%
# then run this code in and provide the link and port number to see the HTML page like this

# %% [markdown]
# ![image.png](attachment:dc5ea8bd-4492-4414-88b9-60f99ac74884.png)

# %%
# once this page will be called, people will enter the inputs

# %%
# after hitting the search button, it will go to the weatherapp url which we provided in the HTML file (check in the HTML file) "<form-action="/weatherapp" method ="POST">"

## that means when we will submit all the data, it will go to that URL, but we don't have the route so we will facing "Not Found" error.


## so we can stop the URL for now and making whole code

# %%
## now we will write a function which will take data, from the form, execute the data and return the result

# %%
from flask import Flask, render_template, request
import requests

app=Flask(__name__)

@app.route('/')
def homepage():
    return render_template("index.html")


@app.route("/weatherapp")
def get_weatherdata():
    url = "https://api.openweathermap.org/data/2.5/weather"
    # we will create a dictionary here for getting the data from the user
    param={
        'q': request.form.get("city"),
        'appid': request.form.get('appid'),
        'units': request.form.get('units')
    }
    response = requests.get(url, params=param)
    data = response.json()

    return f"data : {data}"

if __name__ == '__main__':
    app.run(host='0.0.0.0', port = 5002)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from flask import Flask, render_template, request
#       2 import requests
#       4 app=Flask(__name__)
#
# ModuleNotFoundError: No module named 'flask'

# %%
# here some issues were that is why it is showing that the methods are not allowed because we have not provide the methods.

# %%
# corrected code

# %%
from flask import Flask, render_template, request
import requests

app=Flask(__name__)

@app.route('/')
def homepage():
    return render_template("index.html")


@app.route("/weatherapp", methods = ["POST", "GET"])
def get_weatherdata():
    url = "https://api.openweathermap.org/data/2.5/weather"
    # we will create a dictionary here for getting the data from the user
    param={
        'q': request.form.get("city"),
        'appid': request.form.get('appid'),
        'units': request.form.get('units')
    }
    response = requests.get(url, params=param)
    data = response.json()

    return f"data : {data}"

if __name__ == '__main__':
    app.run(host='0.0.0.0', port = 5002)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 1
# ----> 1 from flask import Flask, render_template, request
#       2 import requests
#       4 app=Flask(__name__)
#
# ModuleNotFoundError: No module named 'flask'

# %%
# after providing all the information, it retunrs the values

# %% [markdown]
# ![image.png](attachment:80f9e165-58a7-4a70-acb5-40abcf9ce2a3.png)

# %%
## on top of the code, we need to make exception handling, loggining.

## and we can even make the code like the outcome comes in structured format.

# %% [markdown]
# #### Deploy this thing to github (Making local to global)

# %%
## if we have to deploy the entire application into global, then we have to make the environments ready in the first place. 

## without making a ready environment, it will be difficult in deployment. 

## we have to resolve dependecies for making the environemnt. 

## cloud is always having a blank system, so we make to install all the libraries, unless installing, the application not work. 

## requrements.txt is used to keep all the dependecies which we like to install. (when we need bulk installation we use the requirements.txt)

# %%
## in the requirements.txt file, we will need these files on this project

Flask==1.1.2
gunicorn==20.0.4
requests==2.24.0

######### always try to take the latest version which you get from the pip repository. go to google and search flask pip open the first page. 


### also you can use without the versions but during enterprise time, it may be difficult to understand the package.
# Out:
#   Cell In[3], line 3
#     Flask==1.1.2
#               ^
# SyntaxError: invalid syntax

# %%
## after this thing is done, next step is I have to push my code from my local system to git and from git we can go to cloud environment. 

## and after that, if we make some changes on the local system after deployment, and then push it to git, it automatically take the changes to the cloud deployment.

# %%
## for pushing the code into git, we have to make a repository to github. 

## go to github, making a repository named "weather_app". after making the repo we can push the app into the github repo using the push command given 

## first go to terminal, then press "ls", (if you don not have gone to the desired folder "here, weather_app is the folder" from which we need to push everything in the repo).

## if you are outside the folder then get inside the folder using "cd weather_app"

## make sure your terminal has on the bash not python.

## you will see there are three files present, app.py, reuquirements.txt, and templates.

## first type "git init" on the terminal

## then type "git add ." (. as we are adding all the files)

## then type "git commit -m "this is my first time commit to push a file into repo""

## when you are doing you may be asked theat providing the email address and the username of the github. after proving those, again check the "git commit" portion to run properly or not. 
# if it doesnot run it will show a red dot, whether the succesfull running is making the blue dot.

## after using all the command, it will ask allow to the github to link with VS code (one time only). during this a code will provide you which need to be copied which will be needed for further usage.

# %%
## now if you reload the repo again, you will see the files are uploaded to the repo.

# %%
## if sometime it shows that the origin already exists, then type "git remote remove origin", then use the command git remote add origin which will work.

# %% [markdown]
# #### cloning a github repo and fetching the code from the github

# %%
# go to vs code, copy the .git link from the repo, go to terminal, 

## type "git clone (url.git)"

## it will copy all the file including the repo folder also.

# %% [markdown]
# #### From github to cloud (3rd Stage)

# %%
## most of the cloud platform asks for credit card for using cloud services. 

## we will use the render.com which provides free cloud platform upto some kind of usage. 

## sign in using google. it will show many option. go to web services.

## now select "Build and deploy from a git provider" 

## now provide unique name for web service, dont change the region, language will be same, 

## Build Command keep it same as it asking where we save the packages required to run the code. 

## Start Command - keep as same. (here we used app.py file so the name will be app in the render cloud. if you have another name then write the name here). 

## choose the package (free). then select "create web service".

# %% [markdown]
# ![image.png](attachment:eb286fe7-8c45-4c4c-8e37-39f097e856dc.png)

# %%
# here you can see the deployment is ready and live.

# %%
# now if you go in the website which is given below, you can find your html page

# %% [markdown]
# ![image.png](attachment:7f2ba964-906e-412e-8c0e-40f7537de025.png)

# %%
# https://weather-app-2-e2k2.onrender.com

# %%
# the above is your website

## open that website , provide all the information and you will get your data.

# %%
# now we will make some changes in this code, like we need the name of the city separately. for that,

# %% [markdown]
# ![image.png](attachment:e93a2307-6f4c-4c69-81df-9aab44ab07b2.png)

# %%
# these kind of changes we made in our code, 

## so we have to go to depolyment once again, 

## but there is a feature present in render.com

## if ypu check in your repo, the new changes is not made any effect, 

## so we need to refresh the repo.

# %% [markdown]
# #### Refreshing repo after making some changes

# %%
## go to terminal and type "git add ."

## "git commit -m "changed code for city""

## "git branch -M main"

## "git push -u origin main"

# %%
# then automatically render.com make changes 

## if does not happen, then click on the manual deploy and then click on the deploy latest commit

# %%
## sometime some packages, even pip may be outdated. so make sure every packages and pip is updated. otherwise the code does not run properly.
